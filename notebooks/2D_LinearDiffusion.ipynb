# %% [markdown]
# ## Imports

# %%
import numpy as np
from matplotlib import pyplot, cm
from mpl_toolkits.mplot3d import Axes3D

import time
from numba import njit
from pyccel.epyccel import epyccel
from pyccel.decorators import types

# %% [markdown]
# ## Pure python function

# %%
def solve_2d_diff_pure(u, nt, dt, dx, dy, nu):
    row, col = u.shape
    
    ###Assign initial conditions
    # set hat function I.C. : u(.5<=x<=1 && .5<=y<=1 ) is 2
    u[int(.5 / dy):int(1 / dy + 1),int(.5 / dx):int(1 / dx + 1)] = 2
    for n in range(nt): 
        for j in range(row):
            for i in range(2, col):
                u[j-1, i-1] = (u[j-1, i-1] + nu * dt / dx**2 * (u[j-1, i] - 2 * u[j-1, i-1] + u[j-1,i-2]) + 
                             nu * dt / dy**2 * (u[j, i-1] - 2 * u[j-1, i-1] + u[j-2,i-1]))
                                      
        u[0, :] = 1
        u[-1, :] = 1
        u[:, 0] = 1
        u[:, -1] = 1
    
    #fill the update of u
        
    return 0

# %% [markdown]
# ## Numba accelerator

# %%
@njit(fastmath=True)
def solve_2d_diff_numba(u, nt, dt, dx, dy, nu):
    row, col = u.shape
    
    ###Assign initial conditions
    # set hat function I.C. : u(.5<=x<=1 && .5<=y<=1 ) is 2
    u[int(.5 / dy):int(1 / dy + 1),int(.5 / dx):int(1 / dx + 1)] = 2
    
    
    #fill the update of u
    for n in range(nt): 
        for j in range(row):
            for i in range(2, col):
                u[j-1, i-1] = (u[j-1, i-1] + nu * dt / dx**2 * (u[j-1, i] - 2 * u[j-1, i-1] + u[j-1,i-2]) + 
                             nu * dt / dy**2 * (u[j, i-1] - 2 * u[j-1, i-1] + u[j-2,i-1]))
                                      
        u[0, :] = 1
        u[-1, :] = 1
        u[:, 0] = 1
        u[:, -1] = 1
        
        
    return 0

# %% [markdown]
# ## Pyccel accelerator

# %%
@types('float[:]', 'int', 'float', 'float','float', 'float')
def solve_2d_diff_pyccel(u, nt, dt, dx, dy, nu):
    row, col = u.shape
    
    ##Assign initial conditions
    #set hat function I.C. : u(.5<=x<=1 && .5<=y<=1 ) is 2
    u[int(.5 / dy):int(1 / dy + 1),int(.5 / dx):int(1 / dx + 1)] = 2
    
    
    #fill the update of u and v
    for n in range(nt): 
        for j in range(row):
            for i in range(2, col):
                u[j-1, i-1] = (u[j-1, i-1] + nu * dt / dx**2 * (u[j-1, i] - 2 * u[j-1, i-1] + u[j-1,i-2]) + 
                             nu * dt / dy**2 * (u[j, i-1] - 2 * u[j-1, i-1] + u[j-2,i-1]))
                                      
        u[0, :] = 1
        u[-1, :] = 1
        u[:, 0] = 1
        u[:, -1] = 1
        
    return 0

# %% [markdown]
# ## Inputs

# %%
###variable declarations
nt = 51
nx = 101
ny = 101
nu = .05
dx = 2 / (nx - 1)
dy = 2 / (ny - 1)
sigma = .25
dt = sigma * dx * dy / nu

x = np.linspace(0, 2, nx)
y = np.linspace(0, 2, ny)

u = np.ones((ny, nx))  # create a 1xn vector of 1's

solve_2d_diff_pure(u, nt, dt, dx, dy, nu)

fig = pyplot.figure(figsize=(7, 5), dpi=100)
ax = fig.gca(projection='3d')                      
X, Y = np.meshgrid(x, y)                            
surf = ax.plot_surface(X, Y, u, cmap=cm.viridis)

# %% [markdown]
# ## Call Funtions

# %% [markdown]
# ### Pure function

# %%
# %timeit solve_2d_diff_pure(u, nt, dt, dx, dy, nu)
# Out:
# 1.4 s ± 22 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# ### Function with numba accelerator

# %%
# %timeit solve_2d_diff_numba(u, nt, dt, dx, dy, nu)
# Out:
# 3.02 ms ± 13.5 µs per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# ### Function with pyccel accelerator

# %%
solve_2d_diff_f90 = epyccel(solve_2d_diff_pyccel)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-20-800e2c6ed56b> in <module>
# ----> 1 solve_2d_diff_f90 = epyccel(solve_2d_diff_pyccel)
#
# ~/.local/lib/python3.8/site-packages/pyccel/epyccel.py in epyccel(python_function_or_module, **kwargs)
#     275     # Serial version
#     276     else:
# --> 277         mod, fun = epyccel_seq( python_function_or_module, **kwargs )
#     278
#     279     # Return Fortran function (if any), otherwise module
#
# ~/.local/lib/python3.8/site-packages/pyccel/epyccel.py in epyccel_seq(function_or_module, language, compiler, mpi_compiler, fflags, accelerator, verbose, debug, includes, libdirs, modules, libs, extra_args, folder)
#     118     try:
#     119         # Generate shared library
# --> 120         execute_pyccel(pymod_filename,
#     121                        verbose     = verbose,
# ...

# %%
# %timeit solve_2d_diff_f90(u, nt, dt, dx, dy, nu)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-2a14bd1d55da> in <module>
# ----> 1 get_ipython().run_line_magic('timeit', 'solve_2d_diff_f90(u, nt, dt, dx, dy, nu)')
#
# ~/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2325                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2326             with self.builtin_trap:
# -> 2327                 result = fn(*args, **kwargs)
#    2328             return result
#    2329
#
# <decorator-gen-53> in timeit(self, line, cell, local_ns)
#
# ~/anaconda3/lib/python3.8/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
# ...
